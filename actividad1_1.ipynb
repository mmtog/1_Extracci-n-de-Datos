# %% [markdown]
# <a href="https://colab.research.google.com/github/mmtog/1_Extracci-n-de-Datos/blob/main/actividad1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 1.1 (Extracción de Datos)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
filtro1 =df[df["NOMBRE_VENDEDOR"]=="LETICIA RAMIREZ HERNANDEZ"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# 5               PÚBLICO EN GENERAL   2.0       BP00243
# 7        ANA BARBARA CRUZ PALACIOS   3.0        TP0001
# ...

# %%
filtro2=df.iloc[[5,15],:]
filtro2
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  \
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ  PÚBLICO EN GENERAL   2.0
# 15  F37058 2022-01-05   DIEGO ARMANDO LEON DURAN  MOLINERA DE MEXICO   5.0
#
#     CVE_ART                                     DESCR  PRECIO_UNITARIO  \
# 5   BP00243     BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
# 15  PT00070  PT-100 1/8"ØX30MM EXT 1.5MT 3HILOS Z/ESP           192.50
#
#     COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 5            49.41                     49.41            474.14
# 15           51.73                    149.60            481.25
#
#     COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 5                   98.82                     187.66                  375.32
# 15                 397.08                      42.90                   84.17

# %%
filtro3=df.iloc[:,1:15]
filtro3
# Out:
#       FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1    2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2    2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3    2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...         ...                        ...                           ...
# 1421 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 1422 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 1423 2022-12-23  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 1424 2022-12-23  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 1425 2022-12-23         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# ...

# %%
df1=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=1)
df1
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...            ...                        ...                           ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
# ...

# %%
filtro4=df1.loc[df1['NOMBRE_VENDEDOR'].isin(["PÚBLICO EN GENERAL", "LETICIA RAMIREZ HERNANDEZ"]), ["PRECIO_UNITARIO"]]
print(filtro4)
# Out:
#             PRECIO_UNITARIO
# FECHA_DOC
# 2022-01-05           434.48
# 2022-01-05          1264.05
# 2022-01-05           172.41
# 2022-01-05           237.07
# 2022-01-05            94.50
# ...                     ...
# 2022-12-23           439.15
# 2022-12-23           712.00
# 2022-12-23           718.60
# 2022-12-23          2182.35
# 2022-12-23          5909.84
#
# [895 rows x 1 columns]

# %%
filtro5=df.head(5)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0   1.0  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1   1.0  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2   7.0    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3   1.0    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4   2.0   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
filtro6=df[df['CANT'] > 3.0]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN  ANA BARBARA CRUZ PALACIOS
# 15    F37058 2022-01-05   DIEGO ARMANDO LEON DURAN         MOLINERA DE MEXICO
# 18    F37061 2022-01-05             ALFREDO CANELA                   ELICAMEX
# 19    F37061 2022-01-05             ALFREDO CANELA                   ELICAMEX
# 26    F37073 2022-01-07  LETICIA RAMIREZ HERNANDEZ      KARINA AGUILAR TORRES
# ...      ...        ...                        ...                        ...
# 1413  F39826 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
# ...

# %%
filtro7=df[(df["PRECIO_UNITARIO"]<1500) & (df ["FECHA_DOC"]=="2022-01-05")]
filtro7
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0   F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1   F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2   F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3   F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 13  F37053 2022-01-05   DIEGO ARMANDO LEON DURAN
# 15  F37058 2022-01-05   DIEGO ARMANDO LEON DURAN
# 16  F37059 2022-01-05   DIEGO ARMANDO LEON DURAN
# 17  F37060 2022-01-05   DIEGO ARMANDO LEON DURAN
# 18  F37061 2022-01-05             ALFREDO CANELA
# 19  F37061 2022-01-05             ALFREDO CANELA
# 20  F37061 2022-01-05             ALFREDO CANELA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0             PÚBLICO EN GENERAL   1.0      TUE00244
# 1   JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2      ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# ...

# %%
filtro8=df[(df["COSTO_TOTAL_CALCULADO"] < 5000)| (df["FECHA_DOC"]=="2022-12-23")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
filtro9=df[~(df["CANT"] > 5) & ~(df["FECHA_DOC"]=="2022-05-15")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0  TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0  TUA00028
# 3             OMAR RODRIGUEZ GOMEZ   1.0    TP0001
# 4               PÚBLICO EN GENERAL   2.0   BP00242
# 5               PÚBLICO EN GENERAL   2.0   BP00243
# ...

# %%
filtro1.to_csv("filtro1.csv")

# %%
filtro2.to_csv("filtro2.csv")

# %%
filtro3.to_csv("filtro3.csv")

# %%
filtro4.to_csv("filtro4.csv")

# %%
filtro5.to_csv("filtro5.csv")

# %%
filtro6.to_csv("filtro6.csv")

# %%
filtro7.to_csv("filtro7.csv")

# %%
filtro8.to_csv("filtro8.csv")

# %%
filtro9.to_csv("filtro9.csv")
